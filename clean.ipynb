# %%
df.to_csv("../data/processed/energy_clean.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.to_csv("../data/processed/energy_clean.csv", index=False)
#
# NameError: name 'df' is not defined
